# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
#import sys
#sys.path.append("/scripts")
#import project_functions

from .scripts import project_functions
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-cd4849c5148f> in <module>
#       3 #import project_functions
#       4
# ----> 5 from .scripts import project_functions
#
# ImportError: attempted relative import with no known parent package

# %%
df_rwq = project_functions.load_and_process('C:\\Users\\PC\\COSC301git\\course-project-group_1031\\data\\raw\\rwq.csv')
df_wwq = project_functions.load_and_process('C:\\Users\\PC\\COSC301git\\course-project-group_1031\\data\\raw\\wwq.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-53db00da5acf> in <module>
# ----> 1 df_rwq = project_functions.load_and_process('C:\\Users\\PC\\COSC301git\\course-project-group_1031\\data\\raw\\rwq.csv')
#       2 df_wwq = project_functions.load_and_process('C:\\Users\\PC\\COSC301git\\course-project-group_1031\\data\\raw\\wwq.csv')
#
# NameError: name 'project_functions' is not defined

# %%
df_rwq=pd.read_csv('C:\\Users\\PC\\COSC301git\\course-project-group_1031\\data\\raw\\rwq.csv')

# %%
df_wwq=pd.read_csv('C:\\Users\\PC\\COSC301git\\course-project-group_1031\\data\\raw\\wwq.csv')

# %%
df_r=(df_rwq.dropna()
          .rename(columns={'fixed acidity':'F_acidity',
                           'volatile acidity':'V_acidity',
                           'free sulfur dioxide':'Free_SO2',
                           'total sulfur dioxide':'Total_SO2'})
          .sort_values("quality", ascending=False)
          .reset_index(drop=True)
         )
df_r
# Out:
#       F_acidity  V_acidity  citric acid  residual sugar  chlorides  Free_SO2  \
# 0          10.7      0.350         0.53            2.60      0.070       5.0
# 1          12.6      0.310         0.72            2.20      0.072       6.0
# 2           7.4      0.360         0.30            1.80      0.074      17.0
# 3           7.2      0.380         0.31            2.00      0.056      15.0
# 4           5.6      0.850         0.05            1.40      0.045      12.0
# ...         ...        ...          ...             ...        ...       ...
# 1594        7.4      1.185         0.00            4.25      0.097       5.0
# 1595        7.1      0.875         0.05            5.70      0.082       3.0
# 1596        8.3      1.020         0.02            3.40      0.084       6.0
# 1597        7.6      1.580         0.00            2.10      0.137       5.0
# 1598       10.4      0.440         0.42            1.50      0.145      34.0
#
# ...

# %%
df_w=(df_wwq.dropna()
          .rename(columns={'fixed acidity':'F_acidity',
                           'volatile acidity':'V_acidity',
                           'free sulfur dioxide':'Free_SO2',
                           'total sulfur dioxide':'Total_SO2'})
          .sort_values("quality", ascending=False)
          .reset_index(drop=True)
         )
df_w
# Out:
#       F_acidity  V_acidity  citric acid  residual sugar  chlorides  Free_SO2  \
# 0           7.4       0.24         0.36            2.00      0.031      27.0
# 1           7.1       0.26         0.49            2.20      0.032      31.0
# 2           6.9       0.36         0.34            4.20      0.018      57.0
# 3           9.1       0.27         0.45           10.60      0.035      28.0
# 4           6.6       0.36         0.29            1.60      0.021      24.0
# ...         ...        ...          ...             ...        ...       ...
# 4893        7.5       0.32         0.24            4.60      0.053       8.0
# 4894        7.6       0.48         0.37            1.20      0.034       5.0
# 4895        8.5       0.26         0.21           16.20      0.074      41.0
# 4896        6.7       0.25         0.26            1.55      0.041     118.5
# 4897        5.8       0.24         0.44            3.50      0.029       5.0
#
# ...

# %%
df_r.isna().sum() 
#check missing value
# Out:
# F_acidity         0
# V_acidity         0
# citric acid       0
# residual sugar    0
# chlorides         0
# Free_SO2          0
# Total_SO2         0
# density           0
# pH                0
# sulphates         0
# alcohol           0
# quality           0
# dtype: int64

# %%
df_w.isna().sum() 
#check missing value
# Out:
# F_acidity         0
# V_acidity         0
# citric acid       0
# residual sugar    0
# chlorides         0
# Free_SO2          0
# Total_SO2         0
# density           0
# pH                0
# sulphates         0
# alcohol           0
# quality           0
# dtype: int64

# %%
df_r.describe(exclude=np.object).T
# Out:
#                  count       mean        std      min      25%       50%  \
# F_acidity       1599.0   8.319637   1.741096  4.60000   7.1000   7.90000
# V_acidity       1599.0   0.527821   0.179060  0.12000   0.3900   0.52000
# citric acid     1599.0   0.270976   0.194801  0.00000   0.0900   0.26000
# residual sugar  1599.0   2.538806   1.409928  0.90000   1.9000   2.20000
# chlorides       1599.0   0.087467   0.047065  0.01200   0.0700   0.07900
# Free_SO2        1599.0  15.874922  10.460157  1.00000   7.0000  14.00000
# Total_SO2       1599.0  46.467792  32.895324  6.00000  22.0000  38.00000
# density         1599.0   0.996747   0.001887  0.99007   0.9956   0.99675
# pH              1599.0   3.311113   0.154386  2.74000   3.2100   3.31000
# sulphates       1599.0   0.658149   0.169507  0.33000   0.5500   0.62000
# alcohol         1599.0  10.422983   1.065668  8.40000   9.5000  10.20000
# quality         1599.0   5.636023   0.807569  3.00000   5.0000   6.00000
#
# ...

# %%
df_w.describe(exclude=np.object).T
# Out:
#                  count        mean        std      min         25%        50%  \
# F_acidity       4898.0    6.854788   0.843868  3.80000    6.300000    6.80000
# V_acidity       4898.0    0.278241   0.100795  0.08000    0.210000    0.26000
# citric acid     4898.0    0.334192   0.121020  0.00000    0.270000    0.32000
# residual sugar  4898.0    6.391415   5.072058  0.60000    1.700000    5.20000
# chlorides       4898.0    0.045772   0.021848  0.00900    0.036000    0.04300
# Free_SO2        4898.0   35.308085  17.007137  2.00000   23.000000   34.00000
# Total_SO2       4898.0  138.360657  42.498065  9.00000  108.000000  134.00000
# density         4898.0    0.994027   0.002991  0.98711    0.991723    0.99374
# pH              4898.0    3.188267   0.151001  2.72000    3.090000    3.18000
# sulphates       4898.0    0.489847   0.114126  0.22000    0.410000    0.47000
# alcohol         4898.0   10.514267   1.230621  8.00000    9.500000   10.40000
# ...

# %%
print(sorted(df_r.quality.unique())) 
#see the rating range for red wine
#from 3 to 8
# Out:
# [3, 4, 5, 6, 7, 8]

# %%
print(sorted(df_w.quality.unique())) 
#see the rating range for withe wine
#from 3 to 9
# Out:
# [3, 4, 5, 6, 7, 8, 9]

# %%
print(df_r.quality.value_counts()) 
#see the frequency of each rate for red wine
#mostly for 5, then 6
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
print(df_w.quality.value_counts()) 
#see the frequency of each rate for white wine
#most wine get 6 then 5, only 5 samples get 9
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
sns.pairplot(data=df_r.select_dtypes(include='number'), 
             corner=True)

# %%
sns.pairplot(data=df_w.select_dtypes(include='number'), 
             corner=True)
