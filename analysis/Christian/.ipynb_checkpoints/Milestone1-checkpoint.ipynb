# %%
import pandas as pd

df1 = pd.read_csv(r'\Users\chris\Downloads\wwq.csv') #First data set being imported into a dataframe

df1.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-d933a8c9f431> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df1 = pd.read_csv(r'data\rwq.csv') #First data set being imported into a dataframe
#       4
#       5 df1.head()
#
# ...

# %%
import pandas as pd

df2 = pd.read_csv(r'\Users\chris\Downloads\rwq.csv') #First data set being imported into a dataframe

df2.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...
