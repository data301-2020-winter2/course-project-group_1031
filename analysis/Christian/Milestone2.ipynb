# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df1 = pd.read_csv(r'\Users\chris\Downloads\rwq.csv')
df2 = pd.read_csv(r'\Users\chris\Downloads\wwq.csv')

# %%
data = pd.read_csv(r'\Users\chris\Downloads\wwq.csv') 
    
df = (   
    pd.DataFrame(data)
    .rename(columns={"alcohol": "alc"}) #Abbreviating longer column names
    .rename(columns={"free sulfur dioxide": "F.S.D."})
    .rename(columns={"total sulfur dioxide": "T.S.D."})
    .sort_values("quality", ascending=False) #Sorting by wine Quality to answer our research question
    .reset_index(drop=True)
)

df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.24         0.36            2.00      0.031
# 1            7.1              0.26         0.49            2.20      0.032
# 2            6.9              0.36         0.34            4.20      0.018
# 3            9.1              0.27         0.45           10.60      0.035
# 4            6.6              0.36         0.29            1.60      0.021
# 5            7.3              0.21         0.29            1.60      0.034
# 6            7.0              0.36         0.32           10.05      0.045
# 7            8.1              0.27         0.35            1.70      0.030
# 8            7.0              0.17         0.36            6.40      0.055
# 9            7.0              0.36         0.32           10.05      0.045
#
#    F.S.D.  T.S.D.  density    pH  sulphates   alc  quality
# 0    27.0   139.0  0.99055  3.28       0.48  12.5        9
# ...

# %%
#Our data set is already clean with no missing values, so our function just cleans up column names, and sorts by wine quality.
#We used Ben's load_and_process function in our scripts folder

def load_and_process(path): 
    
    data = pd.read_csv(path)
    
    newdf = (   
    pd.DataFrame(data)
    .rename(columns={"alcohol": "Alc"}) #Abbreviating longer column names
    .rename(columns={"free sulfur dioxide": "F.S.D."})
    .rename(columns={"total sulfur dioxide": "T.S.D."})
    .sort_values("quality", ascending=False) #Sorting by wine Quality to answer our research question
    .reset_index(drop=True) #Adjusted Index to match our new sorted dataframe
    )

    return newdf

# %%
df3 = load_and_process(r'\Users\chris\Downloads\wwq.csv')
df3.head(15)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4              0.24         0.36            2.00      0.031
# 1             7.1              0.26         0.49            2.20      0.032
# 2             6.9              0.36         0.34            4.20      0.018
# 3             9.1              0.27         0.45           10.60      0.035
# 4             6.6              0.36         0.29            1.60      0.021
# 5             7.3              0.21         0.29            1.60      0.034
# 6             7.0              0.36         0.32           10.05      0.045
# 7             8.1              0.27         0.35            1.70      0.030
# 8             7.0              0.17         0.36            6.40      0.055
# 9             7.0              0.36         0.32           10.05      0.045
# 10            7.0              0.36         0.32           10.50      0.045
# ...

# %%
# Returns expected output, the functions retitles columns and sorts by the wine quality, 
# making it easier for us to further manipulate the df to conduct our analysis

# %%
df4 = load_and_process(r'\Users\chris\Downloads\rwq.csv')
df4.head(15)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            10.7              0.35         0.53             2.6      0.070
# 1             7.2              0.33         0.33             1.7      0.061
# 2             5.6              0.85         0.05             1.4      0.045
# 3             9.1              0.40         0.50             1.8      0.071
# 4             8.6              0.42         0.39             1.8      0.068
# 5             7.8              0.57         0.09             2.3      0.065
# 6             9.4              0.30         0.56             2.8      0.080
# 7            11.3              0.62         0.67             5.2      0.086
# 8             7.2              0.38         0.31             2.0      0.056
# 9            12.6              0.31         0.72             2.2      0.072
# 10            7.4              0.36         0.30             1.8      0.074
# ...

# %%
df3.corr() #Using Correlation Matrix for EDA on first dataframe
# Out:
#                   fixed acidity  volatile acidity  citric acid  \
# fixed acidity          1.000000         -0.022697     0.289181
# volatile acidity      -0.022697          1.000000    -0.149472
# citric acid            0.289181         -0.149472     1.000000
# residual sugar         0.089021          0.064286     0.094212
# chlorides              0.023086          0.070512     0.114364
# F.S.D.                -0.049396         -0.097012     0.094077
# T.S.D.                 0.091070          0.089261     0.121131
# density                0.265331          0.027114     0.149503
# pH                    -0.425858         -0.031915    -0.163748
# sulphates             -0.017143         -0.035728     0.062331
# Alc                   -0.120881          0.067718    -0.075729
# quality               -0.113663         -0.194723    -0.009209
#
#                   residual sugar  chlorides    F.S.D.    T.S.D.   density  \
# ...

# %%
df4.corr() #Using Correlation Matrix for EDA on second dataframe
# Out:
#                   fixed acidity  volatile acidity  citric acid  \
# fixed acidity          1.000000         -0.256131     0.671703
# volatile acidity      -0.256131          1.000000    -0.552496
# citric acid            0.671703         -0.552496     1.000000
# residual sugar         0.114777          0.001918     0.143577
# chlorides              0.093705          0.061298     0.203823
# F.S.D.                -0.153794         -0.010504    -0.060978
# T.S.D.                -0.113181          0.076470     0.035533
# density                0.668047          0.022026     0.364947
# pH                    -0.682978          0.234937    -0.541904
# sulphates              0.183006         -0.260987     0.312770
# Alc                   -0.061668         -0.202288     0.109903
# quality                0.124052         -0.390558     0.226373
#
#                   residual sugar  chlorides    F.S.D.    T.S.D.   density  \
# ...

# %%
#It is worth noting that in both cases, the attribute most correlated with quality is the alcohol content
#For White Wine, the next most highly correlated attribute is pH, followed by Sulphates.
#For Red Wine, the next most highly correlated attribute is Citric Acid, followed by Sulphates.
#It is worth nothing that both alchohol and sulphates were highly correlated in both red and white wine.

# %%
df3.plot(kind='scatter',x='Alc',y='quality')
# Out:
# <AxesSubplot:xlabel='Alc', ylabel='quality'>

# %%
df3.plot(kind='scatter',x='pH',y='quality')
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
#Scatterplots above for the two attributes most highly correlated with quality for white wine

# %%
df4.plot(kind='scatter',x='Alc',y='quality')
# Out:
# <AxesSubplot:xlabel='Alc', ylabel='quality'>

# %%
df3.plot(kind='scatter',x='citric acid',y='quality')
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %%
#Scatterplots above for the two attributes most highly correlated with quality for red wine

# %%
df3.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides       F.S.D.       T.S.D.      density           pH  \
# count  4898.000000  4898.000000  4898.000000  4898.000000  4898.000000
# mean      0.045772    35.308085   138.360657     0.994027     3.188267
# std       0.021848    17.007137    42.498065     0.002991     0.151001
# ...

# %%
df4.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides       F.S.D.       T.S.D.      density           pH  \
# count  1599.000000  1599.000000  1599.000000  1599.000000  1599.000000
# mean      0.087467    15.874922    46.467792     0.996747     3.311113
# std       0.047065    10.460157    32.895324     0.001887     0.154386
# ...
