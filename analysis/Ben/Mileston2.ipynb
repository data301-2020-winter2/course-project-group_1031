# %%
import pandas as pd
import numpy as np

# %%
from pathlib import Path
path1 = Path('C:\\')/'Users'/'carmi'/'Onedrive'/'Desktop'/'DATA_301'/'Milestone_Project'/'wwq.csv'
dfw = pd.read_csv(path1)
path2 = Path('C:\\')/'Users'/'carmi'/'Onedrive'/'Desktop'/'DATA_301'/'Milestone_Project'/'rwq.csv'
dfr = pd.read_csv(path2)

# %%
data =  pd.read_csv(path1)

df1 = (
    pd.DataFrame(data)
    .rename(columns={"residual sugar":"RS"})
    .rename(columns={"free sulfur dioxide":"Free SO2"})
    .rename(columns={"total sulfur dioxide":"Total SO2"})
    .rename(columns={"fixed acidity":"A (fixed)"})
    .rename(columns={"volatile acidity":"A (volatile)"})
    .sort_values("quality", ascending=False)
    .reset_index(drop=True)
)
df1.head(15)
# Out:
#     A (fixed)  A (volatile)  citric acid     RS  chlorides  Free SO2  \
# 0         7.4          0.24         0.36   2.00      0.031      27.0
# 1         7.1          0.26         0.49   2.20      0.032      31.0
# 2         6.9          0.36         0.34   4.20      0.018      57.0
# 3         9.1          0.27         0.45  10.60      0.035      28.0
# 4         6.6          0.36         0.29   1.60      0.021      24.0
# 5         7.3          0.21         0.29   1.60      0.034      29.0
# 6         7.0          0.36         0.32  10.05      0.045      37.0
# 7         8.1          0.27         0.35   1.70      0.030      38.0
# 8         7.0          0.17         0.36   6.40      0.055      42.0
# 9         7.0          0.36         0.32  10.05      0.045      37.0
# 10        7.0          0.36         0.32  10.50      0.045      35.0
# 11        6.4          0.15         0.36   1.80      0.034      43.0
# 12        7.3          0.21         0.29   1.60      0.034      29.0
# 13        7.5          0.28         0.34   4.20      0.028      36.0
# 14        6.4          0.22         0.32   7.20      0.028      15.0
#
#     Total SO2  density    pH  sulphates  alcohol  quality
# 0       139.0  0.99055  3.28       0.48     12.5        9
# 1       113.0  0.99030  3.37       0.42     12.9        9
# 2       119.0  0.98980  3.28       0.36     12.7        9
# 3       124.0  0.99700  3.20       0.46     10.4        9
# 4        85.0  0.98965  3.41       0.61     12.4        9
# 5       118.0  0.99170  3.30       0.50     11.0        8
# 6       131.0  0.99352  3.09       0.33     11.7        8
# 7       103.0  0.99255  3.22       0.63     10.4        8
# 8       123.0  0.99318  3.11       0.50     11.0        8
# 9       131.0  0.99352  3.09       0.33     11.7        8
# 10      135.0  0.99350  3.09       0.33     11.6        8
# 11      150.0  0.99220  3.42       0.69     11.0        8
# 12      118.0  0.99170  3.30       0.50     11.0        8
# 13      116.0  0.99100  2.99       0.41     12.3        8
# 14       83.0  0.99300  3.13       0.55     10.9        8

# %%
def load_and_process(path):

    df2 = (
        pd.read_csv(path)
        .rename(columns={"residual sugar":"RS"})
        .rename(columns={"free sulfur dioxide":"Free SO2"})
        .rename(columns={"total sulfur dioxide":"Total SO2"})
        .rename(columns={"fixed acidity":"A (fixed)"})
        .rename(columns={"volatile acidity":"A (volatile)"})
        .sort_values("quality", ascending=False)
        .reset_index(drop=True)
    )
    
    return df2

# %%
load_and_process(Path('C:\\')/'Users'/'carmi'/'Onedrive'/'Desktop'/'DATA_301'/'Milestone_Project'/'wwq.csv')
# Out:
#       A (fixed)  A (volatile)  citric acid     RS  chlorides  Free SO2  \
# 0           7.4          0.24         0.36   2.00      0.031      27.0
# 1           7.1          0.26         0.49   2.20      0.032      31.0
# 2           6.9          0.36         0.34   4.20      0.018      57.0
# 3           9.1          0.27         0.45  10.60      0.035      28.0
# 4           6.6          0.36         0.29   1.60      0.021      24.0
# ...         ...           ...          ...    ...        ...       ...
# 4893        7.5          0.32         0.24   4.60      0.053       8.0
# 4894        7.6          0.48         0.37   1.20      0.034       5.0
# 4895        8.5          0.26         0.21  16.20      0.074      41.0
# 4896        6.7          0.25         0.26   1.55      0.041     118.5
# 4897        5.8          0.24         0.44   3.50      0.029       5.0
#
#       Total SO2  density    pH  sulphates  alcohol  quality
# 0         139.0  0.99055  3.28       0.48     12.5        9
# 1         113.0  0.99030  3.37       0.42     12.9        9
# 2         119.0  0.98980  3.28       0.36     12.7        9
# 3         124.0  0.99700  3.20       0.46     10.4        9
# 4          85.0  0.98965  3.41       0.61     12.4        9
# ...         ...      ...   ...        ...      ...      ...
# 4893      134.0  0.99580  3.14       0.50      9.1        3
# 4894       57.0  0.99256  3.05       0.54     10.4        3
# 4895      197.0  0.99800  3.02       0.50      9.8        3
# 4896      216.0  0.99490  3.55       0.63      9.4        3
# 4897      109.0  0.99130  3.53       0.43     11.7        3
#
# [4898 rows x 12 columns]
